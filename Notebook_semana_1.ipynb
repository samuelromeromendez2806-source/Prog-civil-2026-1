# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelromeromendez2806-source/Prog-civil-2026-1/blob/main/Notebook_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADAS: ancho y alto en metros
ancho = input(" Ingrese ancho de la ventana en metros")
ancho = float(ancho)
alto = input(" Ingrese alto de la ventana en metros")
alto = float(alto)

# Proceso: calcula lm en pies y av en metros cuadrados
lm = 2 * (ancho + alto) * 3.25
av = (ancho * alto) * 2

print(lm)
print(av)

# SALIDA : Sale longitud de la madera (lm) en pies y Area delk vidrio en metros cuadrados
print("Longitud de la madera (lm) en pies")
print("Area del vidrio en metros cuadrados")
# Out:
#  Ingrese ancho de la ventana en metros1
#  Ingrese alto de la ventana en metros2
# 19.5
# 4.0
# Longitud de la madera (lm) en pies
# Area del vidrio en metros cuadrados
